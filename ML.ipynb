# %%
# importing all necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\aniru\Car Price Prediction\data.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
df['Make'].nunique()
# Out:
# 48

# %% [markdown]
# df.

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Fuel Type'].mode()
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
df['Engine Fuel Type'].fillna("regular unleaded",inplace=True)

# %%
df['Engine HP'].median()
# Out:
# 227.0

# %%
df['Engine HP'].fillna(227.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Cylinders'].mode()
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
df['Engine Cylinders'].fillna(4.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Number of Doors'].mode()
# Out:
# 0    4.0
# Name: Number of Doors, dtype: float64

# %%
df['Number of Doors'].fillna(4.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Market Category'].value_counts()
# Out:
# Crossover                                          1110
# Flex Fuel                                           872
# Luxury                                              855
# Luxury,Performance                                  673
# Hatchback                                           641
#                                                    ...
# Crossover,Exotic,Luxury,Performance                   1
# Exotic,Luxury,High-Performance,Hybrid                 1
# Crossover,Exotic,Luxury,High-Performance              1
# Flex Fuel,Factory Tuner,Luxury,High-Performance       1
# Performance,Hybrid                                    1
# Name: Market Category, Length: 71, dtype: int64

# %%
df['Market Category'].mode()
# Out:
# 0    Crossover
# Name: Market Category, dtype: object

# %%
df.drop(['Market Category'],axis = 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['Year'] = df['Year'].astype(str)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#       Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0          Compact          Coupe           26        19        3916  46135
# 1          Compact    Convertible           28        19        3916  40650
# 2          Compact          Coupe           28        20        3916  36350
# 3          Compact          Coupe           28        18        3916  29450
# 4          Compact    Convertible           28        18        3916  34500
# ...            ...            ...          ...       ...         ...    ...
# 11909      Midsize  4dr Hatchback           23        16         204  46120
# 11910      Midsize  4dr Hatchback           23        16         204  56670
# 11911      Midsize  4dr Hatchback           23        16         204  50620
# 11912      Midsize  4dr Hatchback           23        16         204  50920
# 11913      Midsize          Sedan           26        17          61  28995
#
# [11914 rows x 15 columns]

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                  object
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.corr()
# Out:
# C:\Users\aniru\AppData\Local\Temp\ipykernel_10964\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# Engine HP          1.000000          0.767602        -0.102934    -0.359457
# Engine Cylinders   0.767602          1.000000        -0.141054    -0.607422
# Number of Doors   -0.102934         -0.141054         1.000000     0.118925
# highway MPG       -0.359457         -0.607422         0.118925     1.000000
# city mpg          -0.353894         -0.574382         0.121206     0.886829
# Popularity         0.036823          0.042431        -0.048251    -0.020991
# MSRP               0.661402          0.531171        -0.126081    -0.160043
#
#                   city mpg  Popularity      MSRP
# Engine HP        -0.353894    0.036823  0.661402
# Engine Cylinders -0.574382    0.042431  0.531171
# Number of Doors   0.121206   -0.048251 -0.126081
# highway MPG       0.886829   -0.020991 -0.160043
# city mpg          1.000000   -0.003217 -0.157676
# Popularity       -0.003217    1.000000 -0.048476
# MSRP             -0.157676   -0.048476  1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Make_encode']=lb.fit_transform(df['Make'])

# %%
df['Model_encode']=lb.fit_transform(df['Model'])

# %%
df['Engine Fuel Type_encode']=lb.fit_transform(df['Engine Fuel Type'])

# %%
df['Transmission Type_encode']=lb.fit_transform(df['Transmission Type'])

# %%
df['Driven_Wheels_encode']=lb.fit_transform(df['Driven_Wheels'])

# %%
df['Vehicle Size_encode']=lb.fit_transform(df['Vehicle Size'])

# %%
df['Vehicle Style_encode']=lb.fit_transform(df['Vehicle Style'])

# %%
df.corr()
# Out:
# C:\Users\aniru\AppData\Local\Temp\ipykernel_10964\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           Engine HP  Engine Cylinders  Number of Doors  \
# Engine HP                  1.000000          0.767602        -0.102934
# Engine Cylinders           0.767602          1.000000        -0.141054
# Number of Doors           -0.102934         -0.141054         1.000000
# highway MPG               -0.359457         -0.607422         0.118925
# city mpg                  -0.353894         -0.574382         0.121206
# Popularity                 0.036823          0.042431        -0.048251
# MSRP                       0.661402          0.531171        -0.126081
# Make_encode               -0.226445         -0.265040         0.057339
# Model_encode               0.001831          0.066346         0.138666
# Engine Fuel Type_encode   -0.194818         -0.073143        -0.004793
# Transmission Type_encode  -0.238357         -0.166611        -0.335432
# Driven_Wheels_encode      -0.035007          0.084847        -0.253983
# Vehicle Size_encode        0.207912          0.197754         0.267075
# Vehicle Style_encode       0.013490          0.034029         0.202841
#
#                           highway MPG  city mpg  Popularity      MSRP  \
# Engine HP                   -0.359457 -0.353894    0.036823  0.661402
# Engine Cylinders            -0.607422 -0.574382    0.042431  0.531171
# Number of Doors              0.118925  0.121206   -0.048251 -0.126081
# highway MPG                  1.000000  0.886829   -0.020991 -0.160043
# city mpg                     0.886829  1.000000   -0.003217 -0.157676
# Popularity                  -0.020991 -0.003217    1.000000 -0.048476
# MSRP                        -0.160043 -0.157676   -0.048476  1.000000
# Make_encode                  0.133242  0.150862   -0.297651 -0.107331
# Model_encode                -0.104276 -0.035716   -0.073725 -0.029843
# Engine Fuel Type_encode     -0.171576 -0.184753   -0.059459 -0.114778
# Transmission Type_encode     0.044252  0.048807    0.010095 -0.181742
# Driven_Wheels_encode        -0.003503 -0.011236    0.026987 -0.037943
# Vehicle Size_encode         -0.111000 -0.142728   -0.003995  0.037162
# Vehicle Style_encode         0.027447 -0.041795    0.036024 -0.010193
#
#                           Make_encode  Model_encode  Engine Fuel Type_encode  \
# Engine HP                   -0.226445      0.001831                -0.194818
# Engine Cylinders            -0.265040      0.066346                -0.073143
# Number of Doors              0.057339      0.138666                -0.004793
# highway MPG                  0.133242     -0.104276                -0.171576
# city mpg                     0.150862     -0.035716                -0.184753
# Popularity                  -0.297651     -0.073725                -0.059459
# MSRP                        -0.107331     -0.029843                -0.114778
# Make_encode                  1.000000      0.037819                 0.115823
# Model_encode                 0.037819      1.000000                -0.010129
# Engine Fuel Type_encode      0.115823     -0.010129                 1.000000
# Transmission Type_encode     0.045022     -0.074973                 0.123476
# Driven_Wheels_encode        -0.035689     -0.071920                 0.019046
# Vehicle Size_encode         -0.102262      0.020197                -0.049011
# Vehicle Style_encode        -0.057137     -0.091614                -0.044167
#
#                           Transmission Type_encode  Driven_Wheels_encode  \
# Engine HP                                -0.238357             -0.035007
# Engine Cylinders                         -0.166611              0.084847
# Number of Doors                          -0.335432             -0.253983
# highway MPG                               0.044252             -0.003503
# city mpg                                  0.048807             -0.011236
# Popularity                                0.010095              0.026987
# MSRP                                     -0.181742             -0.037943
# Make_encode                               0.045022             -0.035689
# Model_encode                             -0.074973             -0.071920
# Engine Fuel Type_encode                   0.123476              0.019046
# Transmission Type_encode                  1.000000              0.173338
# Driven_Wheels_encode                      0.173338              1.000000
# Vehicle Size_encode                      -0.305262             -0.132160
# Vehicle Style_encode                     -0.035039              0.099985
#
#                           Vehicle Size_encode  Vehicle Style_encode
# Engine HP                            0.207912              0.013490
# Engine Cylinders                     0.197754              0.034029
# Number of Doors                      0.267075              0.202841
# highway MPG                         -0.111000              0.027447
# city mpg                            -0.142728             -0.041795
# Popularity                          -0.003995              0.036024
# MSRP                                 0.037162             -0.010193
# Make_encode                         -0.102262             -0.057137
# Model_encode                         0.020197             -0.091614
# Engine Fuel Type_encode             -0.049011             -0.044167
# Transmission Type_encode            -0.305262             -0.035039
# Driven_Wheels_encode                -0.132160              0.099985
# Vehicle Size_encode                  1.000000              0.166140
# Vehicle Style_encode                 0.166140              1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Make                      11914 non-null  object
#  1   Model                     11914 non-null  object
#  2   Year                      11914 non-null  object
#  3   Engine Fuel Type          11914 non-null  object
#  4   Engine HP                 11914 non-null  float64
#  5   Engine Cylinders          11914 non-null  float64
#  6   Transmission Type         11914 non-null  object
#  7   Driven_Wheels             11914 non-null  object
#  8   Number of Doors           11914 non-null  float64
#  9   Vehicle Size              11914 non-null  object
#  10  Vehicle Style             11914 non-null  object
#  11  highway MPG               11914 non-null  int64
#  12  city mpg                  11914 non-null  int64
#  13  Popularity                11914 non-null  int64
#  14  MSRP                      11914 non-null  int64
#  15  Make_encode               11914 non-null  int32
#  16  Model_encode              11914 non-null  int32
#  17  Engine Fuel Type_encode   11914 non-null  int32
#  18  Transmission Type_encode  11914 non-null  int32
#  19  Driven_Wheels_encode      11914 non-null  int32
#  20  Vehicle Size_encode       11914 non-null  int32
#  21  Vehicle Style_encode      11914 non-null  int32
# dtypes: float64(3), int32(7), int64(4), object(8)
# memory usage: 1.7+ MB

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#       Vehicle Size  ... city mpg  Popularity   MSRP  Make_encode  \
# 0          Compact  ...       19        3916  46135            4
# 1          Compact  ...       19        3916  40650            4
# 2          Compact  ...       20        3916  36350            4
# 3          Compact  ...       18        3916  29450            4
# 4          Compact  ...       18        3916  34500            4
# ...            ...  ...      ...         ...    ...          ...
# 11909      Midsize  ...       16         204  46120            0
# 11910      Midsize  ...       16         204  56670            0
# 11911      Midsize  ...       16         204  50620            0
# 11912      Midsize  ...       16         204  50920            0
# 11913      Midsize  ...       17          61  28995           25
#
#        Model_encode  Engine Fuel Type_encode  Transmission Type_encode  \
# 0                 1                        8                         3
# 1                 0                        8                         3
# 2                 0                        8                         3
# 3                 0                        8                         3
# 4                 0                        8                         3
# ...             ...                      ...                       ...
# 11909           901                        8                         1
# 11910           901                        8                         1
# 11911           901                        8                         1
# 11912           901                        7                         1
# 11913           902                        9                         1
#
#        Driven_Wheels_encode  Vehicle Size_encode  Vehicle Style_encode
# 0                         3                    0                     8
# 1                         3                    0                     6
# 2                         3                    0                     8
# 3                         3                    0                     8
# 4                         3                    0                     6
# ...                     ...                  ...                   ...
# 11909                     0                    2                     2
# 11910                     0                    2                     2
# 11911                     0                    2                     2
# 11912                     0                    2                     2
# 11913                     2                    2                    14
#
# [11914 rows x 22 columns]

# %%
# creation of ML models

# %%
x = df[['Make_encode', 'Model_encode',
       'Engine Fuel Type_encode', 'Transmission Type_encode',
       'Driven_Wheels_encode', 'Vehicle Size_encode', 'Vehicle Style_encode',
       'Year','Engine HP','Engine Cylinders','highway MPG',
       'city mpg','Popularity']]
y = df['MSRP']

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP', 'Make_encode', 'Model_encode',
#        'Engine Fuel Type_encode', 'Transmission Type_encode',
#        'Driven_Wheels_encode', 'Vehicle Size_encode', 'Vehicle Style_encode'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=2529)

# %%
x_test
# Out:
#        Make_encode  Model_encode  Engine Fuel Type_encode  \
# 11137           47           838                        9
# 10340           15           805                        9
# 3689            31           277                        8
# 7663            45           607                        9
# 2897            25           223                        9
# ...            ...           ...                      ...
# 10700           14           822                        4
# 3880             8           298                        9
# 5338            46           392                        7
# 3927             7           302                        9
# 680             36            50                        9
#
#        Transmission Type_encode  Driven_Wheels_encode  Vehicle Size_encode  \
# 11137                         1                     0                    2
# 10340                         1                     2                    0
# 3689                          1                     0                    2
# 7663                          1                     2                    0
# 2897                          1                     2                    1
# ...                         ...                   ...                  ...
# 10700                         1                     3                    2
# 3880                          1                     2                    1
# 5338                          0                     2                    2
# 3927                          1                     2                    2
# 680                           1                     2                    2
#
#        Vehicle Style_encode  Year  Engine HP  Engine Cylinders  highway MPG  \
# 11137                    15  2016      250.0               5.0           29
# 10340                     3  2015      182.0               4.0           32
# 3689                     15  2016      302.0               6.0           27
# 7663                      2  2014       99.0               4.0           46
# 2897                     14  2001      275.0               8.0           23
# ...                     ...   ...        ...               ...          ...
# 10700                    12  2015      275.0               6.0           19
# 3880                      8  2000      275.0               8.0           25
# 5338                     14  2012      200.0               4.0           32
# 3927                      3  2016      288.0               6.0           22
# 680                      14  1991      140.0               6.0           28
#
#        city mpg  Popularity
# 11137        20         870
# 10340        22         549
# 3689         20         617
# 7663         53        2031
# 2897         15          61
# ...         ...         ...
# 10700        14        5657
# 3880         15        1624
# 5338         24         873
# 3927         15         155
# 680          17         210
#
# [2979 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
lr = LinearRegression()
rf = RandomForestRegressor()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
lr.score(x_test,y_test)
# Out:
# 0.4582773470650777

# %%
rf.score(x_test,y_test)
# Out:
# 0.9405414768269525

# %%
rf.score(x_train,y_train)
# Out:
# 0.9877354177931718

# %%
import pickle

# %%
# save the model to a file using pickle
with open('model.pkl','wb') as model:
    pickle.dump(lr,model)

# %%
np.array(x_test.iloc[0])
# Out:
# array([47, 838, 9, 1, 0, 2, 15, '2016', 250.0, 5.0, 29, 20, 870],
#       dtype=object)
